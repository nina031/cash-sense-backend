# %%
pip install plaid-python
# Out:
# Collecting plaid-pythonNote: you may need to restart the kernel to use updated packages.
#
#   Using cached plaid_python-24.0.0-py3-none-any.whl
# Collecting urllib3>=1.25.3 (from plaid-python)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-dateutil in c:\users\nmessaoudi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plaid-python) (2.8.2)
# Collecting nulltype (from plaid-python)
#   Using cached nulltype-2.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.5 in c:\users\nmessaoudi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil->plaid-python) (1.16.0)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached nulltype-2.3.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: nulltype, urllib3, plaid-python
# Successfully installed nulltype-2.3.1 plaid-python-24.0.0 urllib3-2.2.2
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\nmessaoudi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install django
# Out:
# Collecting django
#   Downloading Django-5.0.7-py3-none-any.whl.metadata (4.1 kB)
# Collecting asgiref<4,>=3.7.0 (from django)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting sqlparse>=0.3.1 (from django)
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tzdata in c:\users\nmessaoudi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from django) (2023.3)
# Downloading Django-5.0.7-py3-none-any.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB 660.6 kB/s eta 0:00:13
#    - -------------------------------------- 0.2/8.2 MB 2.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.2 MB 8.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.2 MB 15.0 MB/s eta 0:00:01
#    -------------------- ------------------- 4.1/8.2 MB 20.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.2 MB 21.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.4/8.2 MB 24.7 MB/s eta 0:00:01
#    ---------------------------------------  8.2/8.2 MB 26.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 23.8 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.2 kB ? eta -:--:--
#    ---------------------------------------- 44.2/44.2 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: sqlparse, asgiref, django
# Successfully installed asgiref-3.8.1 django-5.0.7 sqlparse-0.5.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\nmessaoudi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\nmessaoudi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from plaid.api import plaid_api
from plaid.model.plaid_error import PlaidError
from plaid.model.products import Products
from plaid.model.link_token_create_request import LinkTokenCreateRequest
from plaid.model.country_code import CountryCode
from plaid.model.link_token_get_request import LinkTokenGetRequest
from plaid.model.accounts_get_request import AccountsGetRequest
from plaid.model.transactions_get_request import TransactionsGetRequest
from plaid.configuration import Configuration
from plaid.api_client import ApiClient
from plaid.model.item_public_token_exchange_request import ItemPublicTokenExchangeRequest
from plaid.model.sandbox_public_token_create_request import SandboxPublicTokenCreateRequest
import os

import json
import datetime
from dotenv import load_dotenv, dotenv_values 
# loading variables from .env file

# %%
load_dotenv() 
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_SECRET = os.getenv("PLAID_SECRET")
PLAID_ENV = os.getenv("PLAID_ENV")

# %% [markdown]
# Fake data from sandbox

# %%
# Step 1: Initialize Plaid client configuration


configuration = Configuration(
    host=PLAID_ENV,
    api_key={
        'clientId': PLAID_CLIENT_ID,
        'secret': PLAID_SECRET,
    }
)

api_client = ApiClient(configuration)
client = plaid_api.PlaidApi(api_client)

request = LinkTokenCreateRequest(
    products=[Products('auth'), Products('transactions')],
    client_name="mycompany",
    country_codes=[CountryCode('FR')],
    language='fr',
    user={'client_user_id': 'user_12345'}
)

response = client.link_token_create(request)
link_token = response['link_token']

# %%
# Generate public token
pt_request = SandboxPublicTokenCreateRequest(
    institution_id='ins_117650',
    initial_products=[Products('transactions')]
)
pt_response = client.sandbox_public_token_create(pt_request)

# %%
# The generated public_token can now be
# exchanged for an access_token
exchange_request = ItemPublicTokenExchangeRequest(
    public_token=pt_response['public_token']
)
exchange_response = client.item_public_token_exchange(exchange_request)
access_token = exchange_response.access_token

# %%
# Retrieve account data using access token
request = AccountsGetRequest(
    access_token=access_token
)

try:
    accounts_response = client.accounts_get(request)
    accounts = accounts_response['accounts']
    accounts_list = [account.to_dict() for account in accounts]  # Convert to dictionary
    print(json.dumps(accounts_list, indent=2))
except Exception as e:
    print("Error retrieving accounts:", e)
    if hasattr(e, 'body'):
        try:
            error_response = json.loads(e.body)
            print(json.dumps(error_response, indent=2))
        except json.JSONDecodeError:
            print("Error decoding JSON response")
# Out:
# [
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "balances": {
#       "available": 100.0,
#       "current": 110.0,
#       "limit": null,
#       "iso_currency_code": "GBP",
#       "unofficial_currency_code": null
#     },
#     "mask": "0000",
#     "name": "Plaid Current Account",
#     "official_name": "Plaid Standard Current Account",
#     "type": "depository",
#     "subtype": "checking",
#     "persistent_account_id": "8cfb8beb89b774ee43b090625f0d61d0814322b43bff984eaf60386e"
#   },
#   {
#     "account_id": "65QvBE56GJunpj7E6wVwS7oMBBDZ7ks8PnoVk",
#     "balances": {
#       "available": 200.0,
#       "current": 210.0,
#       "limit": null,
#       "iso_currency_code": "GBP",
#       "unofficial_currency_code": null
#     },
#     "mask": "1111",
#     "name": "Plaid Saving",
#     "official_name": "Plaid Standard Interest Saving",
#     "type": "depository",
#     "subtype": "savings",
#     "persistent_account_id": "211a4e5d8361a3afb7a3886362198c7306e00a313b5aa944c20d34b6"
#   },
#   {
#     "account_id": "X67rwW6GAphRLX5DZ6e6igVjxxPpgLUbv8Ww8",
#     "balances": {
#       "available": null,
#       "current": 410.0,
#       "limit": 2000.0,
#       "iso_currency_code": "GBP",
#       "unofficial_currency_code": null
#     },
#     "mask": "3333",
#     "name": "Plaid Credit Card",
#     "official_name": "Plaid Diamond Credit Card",
#     "type": "credit",
#     "subtype": "credit card"
#   },
#   {
#     "account_id": "D6bBwD6qkKh3l8gzepkpueaxZZWKeXI3LGPKp",
#     "balances": {
#       "available": null,
#       "current": 56302.06,
#       "limit": null,
#       "iso_currency_code": "GBP",
#       "unofficial_currency_code": null
#     },
#     "mask": "8888",
#     "name": "Plaid Mortgage",
#     "official_name": null,
#     "type": "loan",
#     "subtype": "mortgage"
#   },
#   {
#     "account_id": "V6PqgD6LEoh7MKzVe4J4ukwd44G7kWT9ZN83L",
#     "balances": {
#       "available": 4980.0,
#       "current": 5020.0,
#       "limit": 10000.0,
#       "iso_currency_code": "GBP",
#       "unofficial_currency_code": null
#     },
#     "mask": "9999",
#     "name": "Plaid Business Credit Card",
#     "official_name": "Plaid Platinum Small Business Credit Card",
#     "type": "credit",
#     "subtype": "credit card"
#   }
# ]

# %%
# Retrieve transactions data using access token

def serialize_response(obj):
    if isinstance(obj, (datetime.date, datetime.datetime)):
        return obj.isoformat()
    elif isinstance(obj, list):
        return [serialize_response(item) for item in obj]
    elif isinstance(obj, dict):
        return {key: serialize_response(value) for key, value in obj.items()}
    else:
        return obj

start_date = datetime.datetime.now() - datetime.timedelta(days=30)
end_date = datetime.datetime.now()

request = TransactionsGetRequest(
    access_token=access_token,
    start_date=start_date.date(),
    end_date=end_date.date()
)

try:
    transactions_response = client.transactions_get(request)
    transactions = transactions_response['transactions']
    
    # Convert to dictionary and handle serialization
    transactions_list = [serialize_response(transaction.to_dict()) for transaction in transactions]
    
    print(json.dumps(transactions_list, indent=2))
except Exception as e:
    print("Error retrieving transactions:", e)
    if hasattr(e, 'body'):
        try:
            error_response = json.loads(e.body)
            print(json.dumps(error_response, indent=2))
        except json.JSONDecodeError:
            print("Error decoding JSON response")
# Out:
# [
#   {
#     "account_id": "X67rwW6GAphRLX5DZ6e6igVjxxPpgLUbv8Ww8",
#     "account_owner": null,
#     "amount": 500.0,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Clothing and Accessories"
#     ],
#     "category_id": "19012000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Burberry",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-02",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Burberry",
#     "name": "Burberry",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "GENERAL_MERCHANDISE_CLOTHING_AND_ACCESSORIES",
#       "primary": "GENERAL_MERCHANDISE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_MERCHANDISE.png",
#     "transaction_code": null,
#     "transaction_id": "r1zw5n1DMXH4KlWRjbpbSew348N5b9u7k1KoG",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 1073.0,
#     "authorized_date": "2024-08-02",
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Financial",
#       "Loans and Mortgages"
#     ],
#     "category_id": "18020004",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Kensington Mortgage Company",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-02",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Kensington Mortgage Company",
#     "name": "Kensington Mortgage Company",
#     "payment_channel": "online",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "LOAN_PAYMENTS_MORTGAGE_PAYMENT",
#       "primary": "LOAN_PAYMENTS"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png",
#     "transaction_code": null,
#     "transaction_id": "BAGk5bAZBNfJGlXnMvkvFJ9kz6ZVBxi4xgeAE",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 31.0,
#     "authorized_date": "2024-08-02",
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Personal Care"
#     ],
#     "category_id": "18045000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Nail Co",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-02",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Nail Co",
#     "name": "Nail Co",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "PERSONAL_CARE_HAIR_AND_BEAUTY",
#       "primary": "PERSONAL_CARE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_PERSONAL_CARE.png",
#     "transaction_code": null,
#     "transaction_id": "e3AwJW3XB4fQ91LZJ6x6t3kxQNMzdBcr3m67V",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "X67rwW6GAphRLX5DZ6e6igVjxxPpgLUbv8Ww8",
#     "account_owner": null,
#     "amount": 2078.5,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Transfer",
#       "Credit"
#     ],
#     "category_id": "21005000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "AUTOMATIC PAYMENT - THANK",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "LOW",
#       "detailed": "GENERAL_MERCHANDISE_OTHER_GENERAL_MERCHANDISE",
#       "primary": "GENERAL_MERCHANDISE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_MERCHANDISE.png",
#     "transaction_code": null,
#     "transaction_id": "3ojJvAobEVtPoypAXzlzC469WGNm3BiZVEoPN",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "X67rwW6GAphRLX5DZ6e6igVjxxPpgLUbv8Ww8",
#     "account_owner": null,
#     "amount": 500.0,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Food and Drink",
#       "Restaurants"
#     ],
#     "category_id": "13005000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Alfies Fish & Chips",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Alfies Fish & Chips",
#     "name": "Alfies Fish & Chips",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "FOOD_AND_DRINK_RESTAURANT",
#       "primary": "FOOD_AND_DRINK"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png",
#     "transaction_code": null,
#     "transaction_id": "BAGk5bAZBNfJGlXnMvkvFJ9kz6ZVBxi4xgeZV",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 28.0,
#     "authorized_date": "2024-08-01",
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Convenience Stores"
#     ],
#     "category_id": "19015000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "Boscombe Convenience",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "LOW",
#       "detailed": "GENERAL_MERCHANDISE_OTHER_GENERAL_MERCHANDISE",
#       "primary": "GENERAL_MERCHANDISE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_MERCHANDISE.png",
#     "transaction_code": null,
#     "transaction_id": "L6KPbD6aeGh4dPVzBa3aS8Zqv3jpk7ckWED9E",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 24.0,
#     "authorized_date": "2024-08-01",
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Home Improvement"
#     ],
#     "category_id": "18024000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Homeserve",
#         "type": "merchant",
#         "website": "homeserve.com",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/homeserve_493.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "N56A9npEweQpwDzza3vNRyboLbn95z1vAOMke",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/homeserve_493.png",
#     "merchant_entity_id": "N56A9npEweQpwDzza3vNRyboLbn95z1vAOMke",
#     "merchant_name": "Homeserve",
#     "name": "Homeserve",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "HOME_IMPROVEMENT_REPAIR_AND_MAINTENANCE",
#       "primary": "HOME_IMPROVEMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_HOME_IMPROVEMENT.png",
#     "transaction_code": null,
#     "transaction_id": "Z6QBjW6MnwhWo3L6vr5ruLPmqlG8RMte1GQrP",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": "homeserve.com"
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 22.0,
#     "authorized_date": "2024-08-01",
#     "authorized_datetime": null,
#     "category": [
#       "Interest",
#       "Interest Charged"
#     ],
#     "category_id": "15002000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "INTEREST CHARGED INTEREST CHARGED",
#     "payment_channel": "other",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "BANK_FEES_INTEREST_CHARGE",
#       "primary": "BANK_FEES"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_BANK_FEES.png",
#     "transaction_code": null,
#     "transaction_id": "J6lVbD6xjdhE3VaKrjvjuj7EvobgA6cBek7oL",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "X67rwW6GAphRLX5DZ6e6igVjxxPpgLUbv8Ww8",
#     "account_owner": null,
#     "amount": 500.0,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Sporting Goods"
#     ],
#     "category_id": "19046000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "JD Sports",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "LOW",
#       "detailed": "GENERAL_MERCHANDISE_SPORTING_GOODS",
#       "primary": "GENERAL_MERCHANDISE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_MERCHANDISE.png",
#     "transaction_code": null,
#     "transaction_id": "zVPz5XVrWBHvERGeVj1jS5VRvE3WedclXQPqj",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 125.0,
#     "authorized_date": "2024-08-01",
#     "authorized_datetime": null,
#     "category": [
#       "Recreation",
#       "Arts and Entertainment",
#       "Music and Show Venues"
#     ],
#     "category_id": "17001007",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Manchester Arena",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Manchester Arena",
#     "name": "Manchester Arena",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "ENTERTAINMENT_OTHER_ENTERTAINMENT",
#       "primary": "ENTERTAINMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png",
#     "transaction_code": null,
#     "transaction_id": "3ojJvAobEVtPoypAXzlzC469WGNm3BiZVEoMx",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 41.0,
#     "authorized_date": "2024-08-01",
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Financial",
#       "Financial Planning and Investments"
#     ],
#     "category_id": "18020007",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Moneybox",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Moneybox",
#     "name": "Moneybox",
#     "payment_channel": "online",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "TRANSFER_OUT_INVESTMENT_AND_RETIREMENT_FUNDS",
#       "primary": "TRANSFER_OUT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_TRANSFER_OUT.png",
#     "transaction_code": null,
#     "transaction_id": "K6qPVD6d7whexP9gzb8bc8rVRbwAyecRD1wG9",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 73.0,
#     "authorized_date": "2024-08-01",
#     "authorized_datetime": null,
#     "category": [
#       "Community",
#       "Organizations and Associations",
#       "Charities and Non-Profits"
#     ],
#     "category_id": "12015003",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "The Zoological Society of London",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-08-01",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "The Zoological Society of London",
#     "name": "The Zoological Society of London",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "GOVERNMENT_AND_NON_PROFIT_DONATIONS",
#       "primary": "GOVERNMENT_AND_NON_PROFIT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GOVERNMENT_AND_NON_PROFIT.png",
#     "transaction_code": null,
#     "transaction_id": "M6rPZD64Q9hoaP1Q3dyduxVMnbGgw3CLR1nem",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": -3000.0,
#     "authorized_date": "2024-07-31",
#     "authorized_datetime": null,
#     "category": [
#       "Transfer",
#       "Payroll"
#     ],
#     "category_id": "21009000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-07-31",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "Direct Deposit",
#     "payment_channel": "other",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "LOW",
#       "detailed": "INCOME_WAGES",
#       "primary": "INCOME"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_INCOME.png",
#     "transaction_code": null,
#     "transaction_id": "GA9dkDAz4bfbrog4lGyGhanbeR6Z87S67oEnm",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 50.22,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Clothing and Accessories"
#     ],
#     "category_id": "19012000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "H&M",
#         "type": "merchant",
#         "website": "hm.com",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/hm_467.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "5Q8Z246OYvabv1ayDv4wK5m8BJkWZMeZQe4K7",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-31",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/hm_467.png",
#     "merchant_entity_id": "5Q8Z246OYvabv1ayDv4wK5m8BJkWZMeZQe4K7",
#     "merchant_name": "H&M",
#     "name": "H&M",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "GENERAL_MERCHANDISE_CLOTHING_AND_ACCESSORIES",
#       "primary": "GENERAL_MERCHANDISE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_MERCHANDISE.png",
#     "transaction_code": null,
#     "transaction_id": "m7RA9n7DjWFArQeJanmniDwvAzRB6EfgQXqAn",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": "hm.com"
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": -1200.0,
#     "authorized_date": "2024-07-31",
#     "authorized_datetime": null,
#     "category": [
#       "Transfer",
#       "Payroll"
#     ],
#     "category_id": "21009000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Uber",
#         "type": "merchant",
#         "website": "uber.com",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/uber_1060.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-31",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/uber_1060.png",
#     "merchant_entity_id": "eyg8o776k0QmNgVpAmaQj4WgzW9Qzo6O51gdd",
#     "merchant_name": "Uber",
#     "name": "UBER INCOME - PAYROLL",
#     "payment_channel": "other",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "INCOME_WAGES",
#       "primary": "INCOME"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_INCOME.png",
#     "transaction_code": null,
#     "transaction_id": "brkyjWrXKeUj5xLNA9m9TZmrjd6gx7im67D3d",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": "uber.com"
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 120.48,
#     "authorized_date": "2024-07-31",
#     "authorized_datetime": null,
#     "category": [
#       "Recreation",
#       "Arts and Entertainment",
#       "Casinos and Gaming"
#     ],
#     "category_id": "17001014",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Zilch",
#         "type": "financial_institution",
#         "website": "zilch.com",
#         "logo_url": "https://plaid-counterparty-logos.plaid.com/zilch_228.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "QKab6rNARbJp9wOpX2175mv6ydQMBLRy1zQNy",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-31",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Zilch",
#     "name": "zilch london",
#     "payment_channel": "other",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "LOAN_PAYMENTS_PERSONAL_LOAN_PAYMENT",
#       "primary": "LOAN_PAYMENTS"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_LOAN_PAYMENTS.png",
#     "transaction_code": null,
#     "transaction_id": "WVjk4DVMWwHq1rPVQnlncAJkomjgBni6QjLwL",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 10.0,
#     "authorized_date": "2024-07-30",
#     "authorized_datetime": null,
#     "category": [
#       "Food and Drink",
#       "Restaurants"
#     ],
#     "category_id": "13005000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Five Rivers Coffee Company",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-30",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Five Rivers Coffee Company",
#     "name": "Five Rivers Coffee Company",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "FOOD_AND_DRINK_RESTAURANT",
#       "primary": "FOOD_AND_DRINK"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png",
#     "transaction_code": null,
#     "transaction_id": "dBWZJ6BXzeHdyDLZnNmNCMqNK4J59xuJnRgDd",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 75.0,
#     "authorized_date": "2024-07-30",
#     "authorized_datetime": null,
#     "category": [
#       "Travel",
#       "Taxi"
#     ],
#     "category_id": "22016000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Kingshill Cars",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-30",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Kingshill Cars",
#     "name": "Kingshill Cars",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "TRANSPORTATION_TAXIS_AND_RIDE_SHARES",
#       "primary": "TRANSPORTATION"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_TRANSPORTATION.png",
#     "transaction_code": null,
#     "transaction_id": "15NWwE5VgrumaB1EL3K3tjvzKlZeX4cpPrWZV",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 45.0,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Food and Drink",
#       "Restaurants",
#       "Fast Food"
#     ],
#     "category_id": "13005032",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Nando's",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-30",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Nando's",
#     "name": "Nandos",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "FOOD_AND_DRINK_FAST_FOOD",
#       "primary": "FOOD_AND_DRINK"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png",
#     "transaction_code": null,
#     "transaction_id": "gdn7JWdXxwUrRpW7AzlzToMgrj7dVWIE7534e",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 13.0,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Food and Beverage Store"
#     ],
#     "category_id": "19025000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Pokerstars",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-30",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Pokerstars",
#     "name": "Pokerstars",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "ENTERTAINMENT_CASINOS_AND_GAMBLING",
#       "primary": "ENTERTAINMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png",
#     "transaction_code": null,
#     "transaction_id": "qMrAjyMDZ5H89Ql5JDLDczlg8dwaeGfgyRbNE",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 19.99,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Subscription"
#     ],
#     "category_id": "18061000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Spotify",
#         "type": "merchant",
#         "website": "spotify.com",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/spotify_947.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "2373QOZJ18DqqK0KWvgpng3nmVDLMvDvy05RN",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-30",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/spotify_947.png",
#     "merchant_entity_id": "2373QOZJ18DqqK0KWvgpng3nmVDLMvDvy05RN",
#     "merchant_name": "Spotify",
#     "name": "Spotify",
#     "payment_channel": "online",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "ENTERTAINMENT_MUSIC_AND_AUDIO",
#       "primary": "ENTERTAINMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png",
#     "transaction_code": null,
#     "transaction_id": "xy4KXnyq8Lhl63k8Jn9nC3y8lkrgMxc6KelJZ",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": "spotify.com"
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 42.0,
#     "authorized_date": "2024-07-29",
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Furniture and Home Decor"
#     ],
#     "category_id": "19027000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Ceramic Tile Company",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-29",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Ceramic Tile Company",
#     "name": "Ceramic Tile Company",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "HOME_IMPROVEMENT_FURNITURE",
#       "primary": "HOME_IMPROVEMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_HOME_IMPROVEMENT.png",
#     "transaction_code": null,
#     "transaction_id": "jNy7gnN543skgVZwerjrCENvdqRQypI6RapZv",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 146.0,
#     "authorized_date": "2024-07-29",
#     "authorized_datetime": null,
#     "category": [
#       "Food and Drink",
#       "Restaurants"
#     ],
#     "category_id": "13005000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "King Street Brew House",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-29",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "King Street Brew House",
#     "name": "King Street Brew House",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "FOOD_AND_DRINK_RESTAURANT",
#       "primary": "FOOD_AND_DRINK"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png",
#     "transaction_code": null,
#     "transaction_id": "aKg73bKXqJUZnyb6WPBPu5PQLxwjoycZKDd1p",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 40.0,
#     "authorized_date": "2024-07-29",
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Telecommunication Services"
#     ],
#     "category_id": "18063000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Sky",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-29",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Sky",
#     "name": "SKY DIGITAL",
#     "payment_channel": "online",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "RENT_AND_UTILITIES_TELEPHONE",
#       "primary": "RENT_AND_UTILITIES"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_RENT_AND_UTILITIES.png",
#     "transaction_code": null,
#     "transaction_id": "gdn7JWdXxwUrRpW7AzlzToMgrj7dVWIE753MR",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 77.0,
#     "authorized_date": "2024-07-28",
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Personal Care"
#     ],
#     "category_id": "18045000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Elemis Spa",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-28",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Elemis Spa",
#     "name": "Elemis Spa",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "PERSONAL_CARE_HAIR_AND_BEAUTY",
#       "primary": "PERSONAL_CARE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_PERSONAL_CARE.png",
#     "transaction_code": null,
#     "transaction_id": "7mZXVDmbnvFbxG1Dgzazhr4dV5Kj9DidBxvMM",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 18.0,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Supermarkets and Groceries"
#     ],
#     "category_id": "19047000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "HelloFresh",
#         "type": "merchant",
#         "website": "hellofresh.com",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/hellofresh_479.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "a1wEv51o8g7QQEbN2o9NRa3np6AXn0qZ2ZdL9",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-28",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/hellofresh_479.png",
#     "merchant_entity_id": "a1wEv51o8g7QQEbN2o9NRa3np6AXn0qZ2ZdL9",
#     "merchant_name": "HelloFresh",
#     "name": "Hellofresh",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "FOOD_AND_DRINK_GROCERIES",
#       "primary": "FOOD_AND_DRINK"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_FOOD_AND_DRINK.png",
#     "transaction_code": null,
#     "transaction_id": "4D7ZV5DbWwhkLMmDZeBeCRK6j9LdmafJRLDng",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": "hellofresh.com"
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 68.0,
#     "authorized_date": "2024-07-28",
#     "authorized_datetime": null,
#     "category": [
#       "Travel",
#       "Lodging"
#     ],
#     "category_id": "22012000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-07-28",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "MACDONALD HOTELS",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "LOW",
#       "detailed": "ENTERTAINMENT_SPORTING_EVENTS_AMUSEMENT_PARKS_AND_MUSEUMS",
#       "primary": "ENTERTAINMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png",
#     "transaction_code": null,
#     "transaction_id": "pZKAXnZDQbh6PQlXA1n1sZ8D7vadxGipQzRKQ",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 12.0,
#     "authorized_date": "2024-07-27",
#     "authorized_datetime": null,
#     "category": [
#       "Transfer",
#       "Debit"
#     ],
#     "category_id": "21006000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "And Customs",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "LOW",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-27",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
# ...
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 40.0,
#     "authorized_date": "2024-07-09",
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Computers and Electronics"
#     ],
#     "category_id": "19013000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Cartridge Discount",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-09",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Cartridge Discount",
#     "name": "Cartridge Discount",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "GENERAL_MERCHANDISE_ELECTRONICS",
#       "primary": "GENERAL_MERCHANDISE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_MERCHANDISE.png",
#     "transaction_code": null,
#     "transaction_id": "BAGk5bAZBNfJGlXnMvkvFJ9kz6ZVBxi4xgeLV",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 22.0,
#     "authorized_date": "2024-07-09",
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Pharmacies"
#     ],
#     "category_id": "19043000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Lloyds Pharmacy",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-09",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Lloyds Pharmacy",
#     "name": "Lloyds Pharmacy",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "MEDICAL_PHARMACIES_AND_SUPPLEMENTS",
#       "primary": "MEDICAL"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_MEDICAL.png",
#     "transaction_code": null,
#     "transaction_id": "jNy7gnN543skgVZwerjrCENvdqRQypI6RapwP",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 31.0,
#     "authorized_date": "2024-07-08",
#     "authorized_datetime": null,
#     "category": [
#       "Service",
#       "Financial"
#     ],
#     "category_id": "18020000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Autobank Financial Services",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-08",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "Autobank Financial Services",
#     "name": "Autobank Financial Services",
#     "payment_channel": "online",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "GENERAL_SERVICES_ACCOUNTING_AND_FINANCIAL_PLANNING",
#       "primary": "GENERAL_SERVICES"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_SERVICES.png",
#     "transaction_code": null,
#     "transaction_id": "M6rPZD64Q9hoaP1Q3dyduxVMnbGgw3CLR1nzP",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 42.0,
#     "authorized_date": "2024-07-08",
#     "authorized_datetime": null,
#     "category": [
#       "Shops",
#       "Clothing and Accessories"
#     ],
#     "category_id": "19012000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "J D Sports",
#         "type": "merchant",
#         "website": null,
#         "logo_url": null,
#         "confidence_level": "VERY_HIGH",
#         "entity_id": null,
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-08",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": "J D Sports",
#     "name": "J D Sports",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "GENERAL_MERCHANDISE_CLOTHING_AND_ACCESSORIES",
#       "primary": "GENERAL_MERCHANDISE"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_GENERAL_MERCHANDISE.png",
#     "transaction_code": null,
#     "transaction_id": "dBWZJ6BXzeHdyDLZnNmNCMqNK4J59xuJnRg68",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 73.0,
#     "authorized_date": "2024-07-08",
#     "authorized_datetime": null,
#     "category": [
#       "Bank Fees",
#       "Foreign Transaction"
#     ],
#     "category_id": "10005000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-07-08",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "NON-GBP TRANS FEE",
#     "payment_channel": "other",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "BANK_FEES_FOREIGN_TRANSACTION_FEES",
#       "primary": "BANK_FEES"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_BANK_FEES.png",
#     "transaction_code": null,
#     "transaction_id": "65QvBE56GJunpj7E6wVwS7od9Xq6bLC8PewGq",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "X67rwW6GAphRLX5DZ6e6igVjxxPpgLUbv8Ww8",
#     "account_owner": null,
#     "amount": 500.0,
#     "authorized_date": null,
#     "authorized_datetime": null,
#     "category": [
#       "Travel",
#       "Airlines and Aviation Services"
#     ],
#     "category_id": "22001000",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Ryanair",
#         "type": "merchant",
#         "website": "ryanair.com/gb/en",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/ryanair_1556.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "mA0RjEBQDjMWKAKoQy8ODmqwapozBV2mB1XKB",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-08",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/ryanair_1556.png",
#     "merchant_entity_id": "mA0RjEBQDjMWKAKoQy8ODmqwapozBV2mB1XKB",
#     "merchant_name": "Ryanair",
#     "name": "Ryanair",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "TRAVEL_FLIGHTS",
#       "primary": "TRAVEL"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_TRAVEL.png",
#     "transaction_code": null,
#     "transaction_id": "xy4KXnyq8Lhl63k8Jn9nC3y8lkrgMxc6KelNp",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": "ryanair.com/gb/en"
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 27.0,
#     "authorized_date": "2024-07-08",
#     "authorized_datetime": null,
#     "category": [
#       "Bank Fees"
#     ],
#     "category_id": "10000000",
#     "check_number": null,
#     "counterparties": [],
#     "date": "2024-07-08",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": null,
#     "merchant_entity_id": null,
#     "merchant_name": null,
#     "name": "ref: Transaction Fee",
#     "payment_channel": "other",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "LOW",
#       "detailed": "BANK_FEES_OTHER_BANK_FEES",
#       "primary": "BANK_FEES"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_BANK_FEES.png",
#     "transaction_code": null,
#     "transaction_id": "oQqyLnQDeZhDRVxgmydyCdqwDvxpb3uoVbLrQ",
#     "transaction_type": "special",
#     "unofficial_currency_code": null,
#     "website": null
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 42.0,
#     "authorized_date": "2024-07-07",
#     "authorized_datetime": null,
#     "category": [
#       "Recreation",
#       "Arts and Entertainment",
#       "Casinos and Gaming"
#     ],
#     "category_id": "17001014",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "Bet365",
#         "type": "merchant",
#         "website": "bet365.com",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/bet365_1385.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "0Ay3JMg4YgXwAEmBz3Mr9q2bXodoELRoaO3BX",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-07",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/bet365_1385.png",
#     "merchant_entity_id": "0Ay3JMg4YgXwAEmBz3Mr9q2bXodoELRoaO3BX",
#     "merchant_name": "Bet365",
#     "name": "Bet365",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "ENTERTAINMENT_CASINOS_AND_GAMBLING",
#       "primary": "ENTERTAINMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png",
#     "transaction_code": null,
#     "transaction_id": "wwaq5mwlkDfwlW8J1dPdfbGAw7rBK9FP1melr",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": "bet365.com"
#   },
#   {
#     "account_id": "R6dG1D6MpJhw7byjNmWmfj8a66EgjbCao5vmZ",
#     "account_owner": null,
#     "amount": 89.0,
#     "authorized_date": "2024-07-07",
#     "authorized_datetime": null,
#     "category": [
#       "Recreation",
#       "Arts and Entertainment",
#       "Casinos and Gaming"
#     ],
#     "category_id": "17001014",
#     "check_number": null,
#     "counterparties": [
#       {
#         "name": "UniBet",
#         "type": "merchant",
#         "website": "unibet.com",
#         "logo_url": "https://plaid-merchant-logos.plaid.com/unibet_1064.png",
#         "confidence_level": "VERY_HIGH",
#         "entity_id": "8kMw3JVgKo9wgmV3YkVqL2L3QDov93QAJjgJZ",
#         "phone_number": null
#       }
#     ],
#     "date": "2024-07-07",
#     "datetime": null,
#     "iso_currency_code": "GBP",
#     "location": {
#       "address": null,
#       "city": null,
#       "region": null,
#       "postal_code": null,
#       "country": null,
#       "lat": null,
#       "lon": null,
#       "store_number": null
#     },
#     "logo_url": "https://plaid-merchant-logos.plaid.com/unibet_1064.png",
#     "merchant_entity_id": "8kMw3JVgKo9wgmV3YkVqL2L3QDov93QAJjgJZ",
#     "merchant_name": "UniBet",
#     "name": "UniBet",
#     "payment_channel": "in store",
#     "payment_meta": {
#       "reference_number": null,
#       "ppd_id": null,
#       "payee": null,
#       "by_order_of": null,
#       "payer": null,
#       "payment_method": null,
#       "payment_processor": null,
#       "reason": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "personal_finance_category": {
#       "confidence_level": "VERY_HIGH",
#       "detailed": "ENTERTAINMENT_CASINOS_AND_GAMBLING",
#       "primary": "ENTERTAINMENT"
#     },
#     "personal_finance_category_icon_url": "https://plaid-category-icons.plaid.com/PFC_ENTERTAINMENT.png",
#     "transaction_code": null,
#     "transaction_id": "V6PqgD6LEoh7MKzVe4J4ukwvDoZ1XEH9ZE7n6",
#     "transaction_type": "place",
#     "unofficial_currency_code": null,
#     "website": "unibet.com"
#   }
# ]

# %% [markdown]
# Real data from dev environment

# %% [markdown]
# Create ML model to categorize transactions

# %% [markdown]
# Compare with plaid categorization
